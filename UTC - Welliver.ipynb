# %% [markdown]
# # UTC - EDA
#
# Greg Welliver

# %%
# Import relevant libraries and packages.
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.ticker as plticker
import seaborn as sns
sns.set()
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing 
import warnings
from scipy import stats
import matplotlib as mpl
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap
import lightgbm as lgb
from lightgbm import LGBMRegressor
from numpy import mean
from numpy import std
from functools import partial
# %matplotlib inline
from sklearn.linear_model import GammaRegressor
from sklearn.linear_model import TweedieRegressor

import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot
from scipy import stats

from sklearn.datasets import fetch_openml
from sklearn import linear_model, preprocessing, tree, svm, datasets, metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score, auc, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score, f1_score, log_loss
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import xgboost
from xgboost import XGBClassifier
from xgboost import XGBRegressor
import lightgbm as lgb
from lightgbm import LGBMClassifier


from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder as OHE
import sklearn.model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_tweedie_deviance, make_scorer


import xgboost
from xgboost import XGBClassifier
from xgboost import XGBRegressor
import warnings
from subprocess import call
from IPython.display import Image
from datetime import datetime, timedelta, date
import os
import plotly.graph_objects as go
import itertools
from io import StringIO  
import pydotplus

# Seaborn settings
sns.set_context('notebook')
#sns.set_style("whitegrid")
#sns.set_style("white")
style_set = sns.set_style('whitegrid')
pd.options.display.float_format = '{:,}'.format
color_choice1 = 'plum'
color_choice2 = 'lightblue'
color_choice3 = 'lightgreen'
color_choice4 = 'blue'
#ax.yaxis.set_major_formatter('{x:,.0f}')
#sns.set_context('notebook', font_scale = 4)

#from mpl_toolkits.basemap import Basemap
import geopandas as gpd
from shapely.geometry import Point, Polygon
import contextily as ctx

from sklearn.feature_extraction.text import CountVectorizer
import json
from ydata_profiling import ProfileReport
import calendar

# %% [markdown]
# # Part 1 - EDA

# %% [markdown]
# ## Load the data

# %%
# load data
df1 = pd.read_json('logins.json')
dfx1 = pd.read_json('ultimate_data_challenge.json')

# %%
df1.head()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21

# %% [markdown]
# profile = ProfileReport(df1)
# profile

# %% [markdown]
# ## <font color='orange'>Data Quality Observations</font>
# - according to the profiling report, there are 868 duplicate rows (0.9%) - there is no need to remove these, as it is possible that two users logged in at the same time
# - there are not any nulls

# %%
days = list(calendar.day_abbr)
months = list(calendar.month_abbr)

# %%
df2 = df1

# %%
df2['count'] = 1

# %%
df2 = df2.set_index('login_time')

# %%
# group the logins by 15 minute intervals
df2g = df2.groupby(pd.Grouper(freq='15Min')).aggregate(np.sum) 
df2g['count'] = df2g['count'].fillna(0)
df2g.head(10)
# Out:
#                      count
# login_time
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1
# 1970-01-01 21:15:00      4
# 1970-01-01 21:30:00      0
# 1970-01-01 21:45:00      4
# 1970-01-01 22:00:00      9
# 1970-01-01 22:15:00      8

# %% [markdown]
# ## <font color='orange'>View the entire time series</font>

# %%
fig, ax = plt.subplots(figsize = (15 , 7))
ax.set_ylabel("Login Count" , size = 12 )
ax.set_xlabel( "Time" , size = 12 )
ax.yaxis.set_major_formatter('{x:,.0f}')
df2g['count'].plot();

# %% [markdown]
# #### Observations:
# - It does appear that the data follows some sort of cyclical pattern.  We'll need to look more closely at shorter time intervals to get a better sense of the patterns

# %%
df2g = df2g.reset_index()

# %%
df2g.head()
# Out:
#            login_time  count
# 0 1970-01-01 20:00:00      2
# 1 1970-01-01 20:15:00      6
# 2 1970-01-01 20:30:00      9
# 3 1970-01-01 20:45:00      7
# 4 1970-01-01 21:00:00      1

# %%
df2g['timestamp'] = pd.to_datetime(df2g.login_time)

# %%
df2g['month'] = df2g['timestamp'].apply(lambda x: months[x.month])
df2g['day'] = df2g['timestamp'].apply(lambda x: days[x.weekday()])
df2g['hour'] = df2g['timestamp'].apply(lambda x: x.hour)
df2g['time'] = df2g['timestamp'].apply(lambda x: x.time())

# %%
df2g.head()
# Out:
#            login_time  count           timestamp month  day  hour      time
# 0 1970-01-01 20:00:00      2 1970-01-01 20:00:00   Jan  Thu    20  20:00:00
# 1 1970-01-01 20:15:00      6 1970-01-01 20:15:00   Jan  Thu    20  20:15:00
# 2 1970-01-01 20:30:00      9 1970-01-01 20:30:00   Jan  Thu    20  20:30:00
# 3 1970-01-01 20:45:00      7 1970-01-01 20:45:00   Jan  Thu    20  20:45:00
# 4 1970-01-01 21:00:00      1 1970-01-01 21:00:00   Jan  Thu    21  21:00:00

# %% [markdown]
# ## <font color='orange'>Let's look at logins over the course of a day, by aggregating all of the days</font>

# %%
df_day = pd.DataFrame(df2g.groupby('time')['count'].sum().reset_index())
fig, ax = plt.subplots(figsize = (12 , 6))
plt.title("Logins over course of day")
sns.barplot(x = 'time', y = 'count', data = df_day,
            color = color_choice1
            )

ax.set_ylabel("Login Count" , size = 12 )
ax.set_xlabel( "Time" , size = 12 )
ax.yaxis.set_major_formatter('{x:,.0f}')
#plt.xticks(rotation=90)
plt.xticks(np.arange(0, len(df_day)+1, 4))
plt.xticks(rotation=90)
;
# Out:
# ''

# %%
df_day = pd.DataFrame(df2g.groupby('time')['count'].sum().reset_index())
fig, ax = plt.subplots(figsize = (12 , 6))
plt.title("Logins over course of day")
sns.pointplot(x = 'time', y = 'count', data = df_day,
            color = color_choice1
            )

ax.set_ylabel("Login Count" , size = 12 )
ax.set_xlabel( "Time" , size = 12 )
ax.yaxis.set_major_formatter('{x:,.0f}')
#plt.xticks(rotation=90)
plt.xticks(np.arange(0, len(df_day)+1, 4))
plt.xticks(rotation=90)
;
# Out:
# ''

# %% [markdown]
# #### Observations:
# - Logins appear to peak later in the evening and early in the morning, with another peak around midday.  Usage bottoms at around 8AM, and the afternoon displays a meangingful dip from peak hours as well.

# %% [markdown]
# ## <font color='orange'>Let's look at logins per day of week</font>

# %%
day_order = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']
df_month = pd.DataFrame(df2g.groupby('day')['count'].sum().reset_index())
fig, ax = plt.subplots(figsize = (12 , 6))

plt.title("Logins per day of week")
sns.barplot(x = 'day', y = 'count', data = df_month,
            color = color_choice3, order=day_order
            )

ax.set_ylabel("Login Count" , size = 12 )
ax.set_xlabel( "Day" , size = 12 )
ax.yaxis.set_major_formatter('{x:,.0f}')
#plt.xticks(np.arange(0, len(df_month)+1, 4))
plt.xticks(rotation=45)
;
# Out:
# ''

# %% [markdown]
# #### Observations:
# - Usage peaks on Saturday and Sunday, with high volume on Thursday and Friday as well.  Usage is lowest on Monday and Tuesday (earlier in the week).  This is reminiscent of a food delivery service like DoorDash.

# %%
one_week = df2g[df2g['login_time'] < "1970-01-08"]
y = one_week['count']
x = one_week['login_time']

fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
plt.show()

# %%
one_week = df2g[(df2g['login_time'] > "1970-01-08") & (df2g['login_time'] < "1970-01-15")]

y = one_week['count']
x = one_week['login_time']

fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
plt.show()

# %%
one_week = df2g[(df2g['login_time'] > "1970-01-15") & (df2g['login_time'] < "1970-01-22")]

y = one_week['count']
x = one_week['login_time']

fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
plt.show()

# %%
one_week = df2g[(df2g['login_time'] > "1970-01-22") & (df2g['login_time'] < "1970-01-29")]

y = one_week['count']
x = one_week['login_time']

fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
plt.show()

# %% [markdown]
# #### Observations:
# - I selected a few random weeks to see if there was consistency week-to-week.  There does appear to be similar trends on a week-to-week basis.

# %% [markdown]
# ## <font color='orange'>Let's look at logins per month</font>

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Apr']
#df_day = pd.DataFrame(df2g.groupby('time')['count'].sum().sort_values(ascending=False).reset_index())
df_month = pd.DataFrame(df2g.groupby('month')['count'].sum().reset_index())
#df_day

fig, ax = plt.subplots(figsize = (12 , 6))
#plt.figure(figsize=(12,6))
plt.title("Logins per month")
sns.barplot(x = 'month', y = 'count', data = df_month,
            color = color_choice1, order=month_order
            )

#ax.set_ylabel("Damage (USD Billions)" , size = 12 )
ax.set_xlabel( "Month" , size = 12 )
ax.set_ylabel( "Login Count" , size = 12 )
ax.yaxis.set_major_formatter('{x:,.0f}')
#plt.xticks(rotation=90)
#plt.xticks(np.arange(0, len(df_month)+1, 4))
plt.xticks(rotation=45)
;
# Out:
# ''

# %% [markdown]
# #### Observations:
# - Usage steadily increased from the beginning of the year and peaked in March, with a precipitous decline in April. It would be itnerested to see if there was a similar quarterly pattern in the data for the duration of the year.

# %% [markdown]
# #### Let's look at logins over the course of a month

# %%
one_month = df2g[df2g['login_time'] < "1970-02-01"]
y = one_month['count']
x = one_month['login_time']

#plt.figure(figsize=(15,7))
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.show()

# %% [markdown]
# # Part 2 - Experiment and metrics design

# %% [markdown]
# #### Question 1 - primary success metric
# - I would choose the average earnings per day per driver as a success metric for this experiment.  This metric would indicate to us whether the changes we have made have improved the financial rewards for the drivers.  Presumably the drivers need to see improved earnings in order to travel the additional distance across the bridge.

# %% [markdown]
# #### Question 2 - experiment proposal
#
# a) Experiment implementation
#   - A/B test - split population 50/50
#   - for the test variant, we will reimburse drivers that make the trip across the bridge.
#   - control variant, everything would be the same
#   - run the experiment for a period of time where we can get a read of statistical significance on the success metric
#   - closely monitor other metrics that could indicate the overall quality of the experience - match rates, driver NPS, customer NPS, driver frequency of usage, driver retention
#
#
# b) Statistical tests
#   - Null hypothesis is that there is no change in driver earnings as a result of the change
#   - Alternative hypothesis is that there is a change in driver earnings caused by the change
#   - Run experiment at a 95% confidence interval
#
#
# c) Interpretation
#   - If we see evidence to reject the null hypothesis that there is a change in driver earnings caused by the experiment, we would recommend to roll out the feature to the entire population.
#   - We would also want to monitor the other metrics mentioned above to ensure that there aren't any negative impacts on the driver and rider experiences.

# %% [markdown]
# # Part 3 - Predictive modeling

# %% [markdown]
# #### 1. Data cleaning & EDA
#  - Remove duplicates
#  - Handle nulls (below I imputed the median)
#  - check for correlations
#  - create an active_status feature

# %%
dfx1
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 1             Astapor                       0  2014-01-29
# 2             Astapor                       3  2014-01-06
# 3      King's Landing                       9  2014-01-10
# 4          Winterfell                      14  2014-01-27
# ...               ...                     ...         ...
# 49995  King's Landing                       0  2014-01-25
# 49996         Astapor                       1  2014-01-24
# 49997      Winterfell                       0  2014-01-31
# 49998         Astapor                       2  2014-01-14
# 49999         Astapor                       0  2014-01-18
#
#        avg_rating_of_driver          avg_surge last_trip_date    phone  \
# 0                       4.7                1.1     2014-06-17   iPhone
# 1                       5.0                1.0     2014-05-05  Android
# 2                       4.3                1.0     2014-01-07   iPhone
# 3                       4.6 1.1400000000000001     2014-06-29   iPhone
# 4                       4.4               1.19     2014-03-15  Android
# ...                     ...                ...            ...      ...
# 49995                   5.0                1.0     2014-06-05   iPhone
# 49996                   NaN                1.0     2014-01-25   iPhone
# 49997                   5.0                1.0     2014-05-22  Android
# 49998                   3.0                1.0     2014-01-15   iPhone
# 49999                   NaN                1.0     2014-04-20  Android
#
#        surge_pct  ultimate_black_user  weekday_pct  avg_dist  \
# 0           15.4                 True         46.2      3.67
# 1            0.0                False         50.0      8.26
# 2            0.0                False        100.0      0.77
# 3           20.0                 True         80.0      2.36
# 4           11.8                False         82.4      3.13
# ...          ...                  ...          ...       ...
# 49995        0.0                False        100.0      5.63
# 49996        0.0                False          0.0       0.0
# 49997        0.0                 True        100.0      3.86
# 49998        0.0                False        100.0      4.58
# 49999        0.0                False          0.0      3.49
#
#        avg_rating_by_driver
# 0                       5.0
# 1                       5.0
# 2                       5.0
# 3                       4.9
# 4                       4.9
# ...                     ...
# 49995                   4.2
# 49996                   4.0
# 49997                   5.0
# 49998                   3.5
# 49999                   5.0
#
# [50000 rows x 12 columns]

# %%
#profile = ProfileReport(dfx1)
#profile

# %%
#Drop duplicates
dfx1.drop_duplicates(keep='first', inplace=True)

# %%
dfx1 = dfx1.reset_index(drop=True)

# %%
dfx1.dtypes
# Out:
# city                       object
# trips_in_first_30_days      int64
# signup_date                object
# avg_rating_of_driver      float64
# avg_surge                 float64
# last_trip_date             object
# phone                      object
# surge_pct                 float64
# ultimate_black_user          bool
# weekday_pct               float64
# avg_dist                  float64
# avg_rating_by_driver      float64
# dtype: object

# %%
dfx1.signup_date.min()
# Out:
# '2014-01-01'

# %%
dfx1.signup_date.max()
# Out:
# '2014-01-31'

# %%
dfx1.last_trip_date.max()
# Out:
# '2014-07-01'

# %%
dfx1.last_trip_date.min()
# Out:
# '2014-01-01'

# %%
dfx1.isna().sum()
# Out:
# city                         0
# trips_in_first_30_days       0
# signup_date                  0
# avg_rating_of_driver      8119
# avg_surge                    0
# last_trip_date               0
# phone                      396
# surge_pct                    0
# ultimate_black_user          0
# weekday_pct                  0
# avg_dist                     0
# avg_rating_by_driver       201
# dtype: int64

# %% [markdown]
# #### Handle the nulls

# %%
# start with avg_rating_of_driver
dfx1.avg_rating_of_driver.describe()
# Out:
# count             41,873.0
# mean    4.6015117139921236
# std     0.6173599585421049
# min                    1.0
# 25%                    4.3
# 50%                    4.9
# 75%                    5.0
# max                    5.0
# Name: avg_rating_of_driver, dtype: float64

# %%
dfx1.avg_rating_of_driver.median()
# Out:
# 4.9

# %%
dfx1.avg_rating_of_driver.hist()
# Out:
# <AxesSubplot:>

# %%
# impute with median for avg_rating_of_driver and avg_rating_by_driver
dfx1['avg_rating_of_driver'] = dfx1['avg_rating_of_driver'].fillna(dfx1['avg_rating_of_driver'].median())
dfx1['avg_rating_by_driver'] = dfx1['avg_rating_by_driver'].fillna(dfx1['avg_rating_by_driver'].median())

# %%
dfx1.phone.value_counts()
# Out:
# iPhone     34578
# Android    15018
# Name: phone, dtype: int64

# %%
# with 2/3 of phone values as iPhone, simply fill the remaining nulls as iPhone
dfx1['phone'] = dfx1['phone'].fillna('iPhone')

# %%
dfx1['ltd_timestamp'] = pd.to_datetime(dfx1['last_trip_date'], format="%Y-%m-%d")
dfx1.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#            avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0                1.1     2014-06-17   iPhone       15.4                 True
# 1                1.0     2014-05-05  Android        0.0                False
# 2                1.0     2014-01-07   iPhone        0.0                False
# 3 1.1400000000000001     2014-06-29   iPhone       20.0                 True
# 4               1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver ltd_timestamp
# 0         46.2      3.67                   5.0    2014-06-17
# 1         50.0      8.26                   5.0    2014-05-05
# 2        100.0      0.77                   5.0    2014-01-07
# 3         80.0      2.36                   4.9    2014-06-29
# 4         82.4      3.13                   4.9    2014-03-15

# %% [markdown]
# Since we weren't given information on what is the current date of the analysis, I assume that the current date is the most recent last_trip_date

# %%
# set an active cutoff date of the latest last_trip_date - 30 days
dfx1['active_cutoff'] = pd.to_datetime(dfx1.last_trip_date.max(), format="%Y-%m-%d") - timedelta(days=30)

# %%
dfx1.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#            avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0                1.1     2014-06-17   iPhone       15.4                 True
# 1                1.0     2014-05-05  Android        0.0                False
# 2                1.0     2014-01-07   iPhone        0.0                False
# 3 1.1400000000000001     2014-06-29   iPhone       20.0                 True
# 4               1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver ltd_timestamp active_cutoff
# 0         46.2      3.67                   5.0    2014-06-17    2014-06-01
# 1         50.0      8.26                   5.0    2014-05-05    2014-06-01
# 2        100.0      0.77                   5.0    2014-01-07    2014-06-01
# 3         80.0      2.36                   4.9    2014-06-29    2014-06-01
# 4         82.4      3.13                   4.9    2014-03-15    2014-06-01

# %%
# create active status Y or N
dfx1['active_status'] = np.where((dfx1['ltd_timestamp'] >= dfx1['active_cutoff']), 'Y', 'N')

# %%
dfx1.head(10)
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
# 5      Winterfell                       2  2014-01-09                   3.5
# 6         Astapor                       1  2014-01-24                   4.9
# 7      Winterfell                       2  2014-01-28                   5.0
# 8      Winterfell                       2  2014-01-21                   4.5
# 9      Winterfell                       1  2014-01-03                   4.9
#
#            avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0                1.1     2014-06-17   iPhone       15.4                 True
# 1                1.0     2014-05-05  Android        0.0                False
# 2                1.0     2014-01-07   iPhone        0.0                False
# 3 1.1400000000000001     2014-06-29   iPhone       20.0                 True
# 4               1.19     2014-03-15  Android       11.8                False
# 5                1.0     2014-06-06   iPhone        0.0                 True
# 6                1.0     2014-01-25  Android        0.0                False
# 7                1.0     2014-01-29   iPhone        0.0                False
# 8                1.0     2014-02-01  Android        0.0                False
# 9                1.0     2014-01-05  Android        0.0                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver ltd_timestamp active_cutoff  \
# 0         46.2      3.67                   5.0    2014-06-17    2014-06-01
# 1         50.0      8.26                   5.0    2014-05-05    2014-06-01
# 2        100.0      0.77                   5.0    2014-01-07    2014-06-01
# 3         80.0      2.36                   4.9    2014-06-29    2014-06-01
# 4         82.4      3.13                   4.9    2014-03-15    2014-06-01
# 5        100.0     10.56                   5.0    2014-06-06    2014-06-01
# 6        100.0      3.95                   4.0    2014-01-25    2014-06-01
# 7        100.0      2.04                   5.0    2014-01-29    2014-06-01
# 8        100.0      4.36                   5.0    2014-02-01    2014-06-01
# 9          0.0      2.37                   5.0    2014-01-05    2014-06-01
#
#   active_status
# 0             Y
# 1             N
# 2             N
# 3             Y
# 4             N
# 5             Y
# 6             N
# 7             N
# 8             N
# 9             N

# %%
# drop columns that we created to get active status
dfx1 = dfx1.drop(['ltd_timestamp', 'active_cutoff'], axis=1)

# %%
# drop columns that most likely don't have predictive value; drop avg_surge since it is highly correlated with surge_pct, and surge_pct has higher feature importance
dfx1 = dfx1.drop(['signup_date', 'avg_surge', 'last_trip_date'], axis=1)

# %%
dfx1.active_status.value_counts()
# Out:
# N    31188
# Y    18804
# Name: active_status, dtype: int64

# %%
len(dfx1.loc[(dfx1['active_status'] == 'Y')]) / len(dfx1)
# Out:
# 0.3761401824291887

# %% [markdown]
# ### 37.6% of users were retained

# %%
corrmat = dfx1.corr()
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(round(corrmat,2), annot=True, ax=ax, cmap='magma',fmt='.2f',
                 linewidths=.05)

f.subplots_adjust(top=0.93)

# %% [markdown]
# avg_surge and surge_pct are highly correlated - it may be wise to drop one of these variables

# %%
dfx1.head()
# Out:
#              city  trips_in_first_30_days  avg_rating_of_driver    phone  \
# 0  King's Landing                       4                   4.7   iPhone
# 1         Astapor                       0                   5.0  Android
# 2         Astapor                       3                   4.3   iPhone
# 3  King's Landing                       9                   4.6   iPhone
# 4      Winterfell                      14                   4.4  Android
#
#    surge_pct  ultimate_black_user  weekday_pct  avg_dist  \
# 0       15.4                 True         46.2      3.67
# 1        0.0                False         50.0      8.26
# 2        0.0                False        100.0      0.77
# 3       20.0                 True         80.0      2.36
# 4       11.8                False         82.4      3.13
#
#    avg_rating_by_driver active_status
# 0                   5.0             Y
# 1                   5.0             N
# 2                   5.0             N
# 3                   4.9             Y
# 4                   4.9             N

# %%
sns.countplot(x='ultimate_black_user', data=dfx1, hue='active_status');

# %% [markdown]
# Comment: it appears that users that are not ultimate_black_users have a much higher churn rate

# %%
sns.countplot(x='city', data=dfx1, hue='active_status');

# %% [markdown]
# Comment: it appears that Astapor city and Winterfell have a much higher churn rate

# %%
sns.countplot(x='phone', data=dfx1, hue='active_status');

# %% [markdown]
# Comment: it appears that users that Android users have a much higher churn rate

# %% [markdown]
# #### 2. Predictive model
#  - Created active_status column, which is used as the target variable
#  - Employ a few different classification algorithms and see which model performs the best
#      - Random Forest
#      - LightGBM
#  - The LightGBM produced the better results of the two, with an F1 score of .78.

# %% [markdown]
# ##### Create dummy variables for categorical data types

# %%
# isolate categorical variables
categorical_features = dfx1.select_dtypes(include=['object'])

# exclude dependent variable
categorical_features = categorical_features.drop(columns = ['active_status'])

dfx2 = pd.concat([dfx1.drop(categorical_features, axis=1), pd.get_dummies(categorical_features)], axis=1)

# %% [markdown]
# ##### Split data into training and testing subsets

# %%
# Create the X and y matrices from the dataframe
X = dfx2.drop(columns = ['active_status'])
y = dfx2['active_status']

# %%
# train_test_split; reserve 20% for test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=23)

# %%
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)

# %% [markdown]
# ##### Scaling and Transforming Numeric Features

# %%
# Create subset of only the numeric columns
numeric_df = dfx2.select_dtypes(include=['int', 'float'])

# %%
numeric_column_names = list(numeric_df.columns)

# %%
# let's look at the distribution of numeric variables
numeric_df.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5)

# %%
# isolate numeric features of X_train and X_test
numeric_df_X_train = X_train.select_dtypes(include=['int', 'float'])
numeric_df_X_test = X_test.select_dtypes(include=['int', 'float'])

# %%
# scale X_train and X_test
# this should make all values between 0 and 1
from sklearn.preprocessing import MinMaxScaler

# create model, fit, and transform
MM_scaler = MinMaxScaler()
numeric_df_mm_X_train = MM_scaler.fit_transform(numeric_df_X_train)
numeric_df_mm_X_test = MM_scaler.fit_transform(numeric_df_X_test)

# convert back to dataframe for plotting
numeric_df_mm_X_train = pd.DataFrame(numeric_df_mm_X_train)
numeric_df_mm_X_train.columns = numeric_column_names
numeric_df_mm_X_test = pd.DataFrame(numeric_df_mm_X_test)
numeric_df_mm_X_test.columns = numeric_column_names

#numeric_df_mm_X_train
# numeric_df_mm_X_test.hist(figsize=(15,10))
# plt.subplots_adjust(hspace=0.5)

# %%
for column_name in numeric_column_names:
    X_train[column_name] = numeric_df_mm_X_train[column_name]

# %%
for column_name in numeric_column_names:
    X_test[column_name] = numeric_df_mm_X_test[column_name]

# %% [markdown]
# ### Load the datasets

# %%
X_train = pd.read_csv('X_train.csv', index_col =[0])
X_test = pd.read_csv('X_test.csv', index_col =[0])
y_train = pd.read_csv('y_train.csv', index_col =[0]) 
y_test = pd.read_csv('y_test.csv', index_col =[0])

eval_set = [(X_train, y_train), (X_test, y_test)]

# %% [markdown]
# #### <font color='orange'>Random Forest</font>

# %%
# using 3 estimators
rf_clf = RandomForestClassifier(random_state = 23, n_jobs=-1)
rf_clf.fit(X_train, y_train.values.ravel())
y_pred = rf_clf.predict(X_test)

# let's look at classification report
print("Classification Report for Training Data")
print(classification_report(y_train, rf_clf.predict(X_train)))
print("Classification Report for Test Data")
print(classification_report(y_test, rf_clf.predict(X_test)))
# Out:
# Classification Report for Training Data
#               precision    recall  f1-score   support
#
#            N       1.00      1.00      1.00     24940
#            Y       1.00      0.99      1.00     15053
#
#     accuracy                           1.00     39993
#    macro avg       1.00      1.00      1.00     39993
# weighted avg       1.00      1.00      1.00     39993
#
# Classification Report for Test Data
#               precision    recall  f1-score   support
#
#            N       0.77      0.79      0.78      6248
#            Y       0.64      0.61      0.62      3751
#
#     accuracy                           0.72      9999
#    macro avg       0.70      0.70      0.70      9999
# weighted avg       0.72      0.72      0.72      9999

# %%
feature_importance = rf_clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(8,8))
plt.barh(pos, feature_importance[sorted_idx], align='center', color = 'plum')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 12

# %% [markdown]
# #### Hyperparameter Tuning- RandomizedSearchCV

# %%
# set the parameter grid
param_grid = {
    'n_estimators': [25, 50, 100, 150],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [3, 6, 9],
}

# %%
# comment out to avoid lengthy run
# rf_clf_cv = RandomizedSearchCV(RandomForestClassifier(random_state=23),
#                                    param_grid)
# rf_clf_cv.fit(X_train, y_train.values.ravel())
# print(rf_clf_cv.best_estimator_)

# %% [markdown]
# ##### Output of above:
#
# 1st run
# RandomForestClassifier(max_depth=9, max_features='log2', max_leaf_nodes=9,
#                        n_estimators=150, random_state=23)
#
# 2nd run
# RandomForestClassifier(max_depth=9, max_features='log2', max_leaf_nodes=9,
#                        random_state=23)

# %%
# update with CV
rf_clf_cv = RandomForestClassifier(max_depth=9, max_features='log2', max_leaf_nodes=9, n_estimators=150, random_state=23)
rf_clf_cv.fit(X_train, y_train.values.ravel())
y_pred = rf_clf_cv.predict(X_test)

# let's look at classification report
print("Classification Report for Training Data")
print(classification_report(y_train, rf_clf_cv.predict(X_train)))
print("Classification Report for Test Data")
print(classification_report(y_test, rf_clf_cv.predict(X_test)))
# Out:
# Classification Report for Training Data
#               precision    recall  f1-score   support
#
#            N       0.76      0.89      0.82     24940
#            Y       0.75      0.53      0.63     15053
#
#     accuracy                           0.76     39993
#    macro avg       0.76      0.71      0.72     39993
# weighted avg       0.76      0.76      0.75     39993
#
# Classification Report for Test Data
#               precision    recall  f1-score   support
#
#            N       0.76      0.90      0.83      6248
#            Y       0.76      0.54      0.63      3751
#
#     accuracy                           0.76      9999
#    macro avg       0.76      0.72      0.73      9999
# weighted avg       0.76      0.76      0.75      9999

# %%
feature_importance = rf_clf_cv.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(8,8))
plt.barh(pos, feature_importance[sorted_idx], align='center', color = 'plum')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 12

# %% [markdown]
# #### <font color='orange'>Light GBM</font>

# %%
# define the model
lgbm = LGBMClassifier(random_state=1234)
lgbm.fit(X_train, y_train, early_stopping_rounds=20, eval_set=eval_set)
# Out:
# /Users/gregwelliver/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/gregwelliver/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.633454	valid_1's binary_logloss: 0.632808
# Training until validation scores don't improve for 20 rounds
# [2]	training's binary_logloss: 0.610226	valid_1's binary_logloss: 0.609469
# [3]	training's binary_logloss: 0.590362	valid_1's binary_logloss: 0.589662
# [4]	training's binary_logloss: 0.573479	valid_1's binary_logloss: 0.572931
# [5]	training's binary_logloss: 0.55959	valid_1's binary_logloss: 0.559607
# [6]	training's binary_logloss: 0.547311	valid_1's binary_logloss: 0.547257
# [7]	training's binary_logloss: 0.536298	valid_1's binary_logloss: 0.53734
# [8]	training's binary_logloss: 0.526826	valid_1's binary_logloss: 0.528736
# [9]	training's binary_logloss: 0.519294	valid_1's binary_logloss: 0.521187
# [10]	training's binary_logloss: 0.511166	valid_1's binary_logloss: 0.514365
# [11]	training's binary_logloss: 0.504883	valid_1's binary_logloss: 0.508823
# [12]	training's binary_logloss: 0.498515	valid_1's binary_logloss: 0.503322
# [13]	training's binary_logloss: 0.493416	valid_1's binary_logloss: 0.498266
# [14]	training's binary_logloss: 0.488634	valid_1's binary_logloss: 0.494406
# [15]	training's binary_logloss: 0.484632	valid_1's binary_logloss: 0.490341
# [16]	training's binary_logloss: 0.48072	valid_1's binary_logloss: 0.488907
# [17]	training's binary_logloss: 0.477886	valid_1's binary_logloss: 0.486338
# [18]	training's binary_logloss: 0.475015	valid_1's binary_logloss: 0.48358
# [19]	training's binary_logloss: 0.47211	valid_1's binary_logloss: 0.483273
# [20]	training's binary_logloss: 0.469659	valid_1's binary_logloss: 0.481469
# [21]	training's binary_logloss: 0.467594	valid_1's binary_logloss: 0.479552
# [22]	training's binary_logloss: 0.465818	valid_1's binary_logloss: 0.478049
# [23]	training's binary_logloss: 0.463968	valid_1's binary_logloss: 0.476798
# [24]	training's binary_logloss: 0.462057	valid_1's binary_logloss: 0.47796
# [25]	training's binary_logloss: 0.460591	valid_1's binary_logloss: 0.476631
# [26]	training's binary_logloss: 0.459337	valid_1's binary_logloss: 0.475678
# [27]	training's binary_logloss: 0.458002	valid_1's binary_logloss: 0.474626
# [28]	training's binary_logloss: 0.456879	valid_1's binary_logloss: 0.473704
# [29]	training's binary_logloss: 0.455961	valid_1's binary_logloss: 0.472942
# [30]	training's binary_logloss: 0.454807	valid_1's binary_logloss: 0.472667
# [31]	training's binary_logloss: 0.453973	valid_1's binary_logloss: 0.472294
# [32]	training's binary_logloss: 0.452813	valid_1's binary_logloss: 0.472611
# [33]	training's binary_logloss: 0.452011	valid_1's binary_logloss: 0.472391
# [34]	training's binary_logloss: 0.451042	valid_1's binary_logloss: 0.473011
# [35]	training's binary_logloss: 0.450287	valid_1's binary_logloss: 0.472834
# [36]	training's binary_logloss: 0.449646	valid_1's binary_logloss: 0.472535
# [37]	training's binary_logloss: 0.448731	valid_1's binary_logloss: 0.472315
# [38]	training's binary_logloss: 0.448134	valid_1's binary_logloss: 0.472196
# [39]	training's binary_logloss: 0.44731	valid_1's binary_logloss: 0.472131
# [40]	training's binary_logloss: 0.446757	valid_1's binary_logloss: 0.472092
# [41]	training's binary_logloss: 0.446143	valid_1's binary_logloss: 0.472122
# [42]	training's binary_logloss: 0.445671	valid_1's binary_logloss: 0.472206
# [43]	training's binary_logloss: 0.444547	valid_1's binary_logloss: 0.472504
# [44]	training's binary_logloss: 0.44412	valid_1's binary_logloss: 0.472599
# [45]	training's binary_logloss: 0.443387	valid_1's binary_logloss: 0.473049
# [46]	training's binary_logloss: 0.442813	valid_1's binary_logloss: 0.472746
# [47]	training's binary_logloss: 0.44228	valid_1's binary_logloss: 0.473575
# [48]	training's binary_logloss: 0.441887	valid_1's binary_logloss: 0.473658
# [49]	training's binary_logloss: 0.44144	valid_1's binary_logloss: 0.473445
# [50]	training's binary_logloss: 0.441015	valid_1's binary_logloss: 0.473669
# [51]	training's binary_logloss: 0.440509	valid_1's binary_logloss: 0.473849
# [52]	training's binary_logloss: 0.439545	valid_1's binary_logloss: 0.474987
# [53]	training's binary_logloss: 0.439108	valid_1's binary_logloss: 0.475968
# [54]	training's binary_logloss: 0.438595	valid_1's binary_logloss: 0.475939
# [55]	training's binary_logloss: 0.438092	valid_1's binary_logloss: 0.476205
# [56]	training's binary_logloss: 0.437717	valid_1's binary_logloss: 0.476484
# [57]	training's binary_logloss: 0.437318	valid_1's binary_logloss: 0.477049
# [58]	training's binary_logloss: 0.436875	valid_1's binary_logloss: 0.477153
# [59]	training's binary_logloss: 0.436101	valid_1's binary_logloss: 0.477365
# [60]	training's binary_logloss: 0.435758	valid_1's binary_logloss: 0.477581
# Early stopping, best iteration is:
# [40]	training's binary_logloss: 0.446757	valid_1's binary_logloss: 0.472092
# LGBMClassifier(random_state=1234)

# %%
print("Classification Report for Training Data")
print(classification_report(y_train, lgbm.predict(X_train)))
print("Classification Report for Test Data")
print(classification_report(y_test, lgbm.predict(X_test)))
# Out:
# Classification Report for Training Data
#               precision    recall  f1-score   support
#
#            N       0.81      0.87      0.84     24940
#            Y       0.76      0.67      0.71     15053
#
#     accuracy                           0.79     39993
#    macro avg       0.78      0.77      0.78     39993
# weighted avg       0.79      0.79      0.79     39993
#
# Classification Report for Test Data
#               precision    recall  f1-score   support
#
#            N       0.80      0.87      0.83      6248
#            Y       0.75      0.64      0.69      3751
#
#     accuracy                           0.78      9999
#    macro avg       0.78      0.75      0.76      9999
# weighted avg       0.78      0.78      0.78      9999

# %%
feature_importance = lgbm.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(8,8))
plt.barh(pos, feature_importance[sorted_idx], align='center', color = 'plum')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 12

# %%
param_grid = {
    'learning_rate': [0.1, 0.3],
    'max_depth': [3, 6, 9],
    'n_estimators': [50, 100, 150],
    'num_leaves': [10, 30, 50],
    'colsample_bytree': [.3, .5, .8]
}

# %%
# %%time
#markdown since it takes so long to run
# random_search = RandomizedSearchCV(LGBMClassifier(random_state=23),
#                                    param_grid, n_jobs=-1)
# random_search.fit(X_train, y_train.values.ravel())
# print(random_search.best_estimator_)

# %% [markdown]
# Ouput:
#     LGBMClassifier(colsample_bytree=0.8, max_depth=9, n_estimators=150,
#                num_leaves=10, random_state=23)

# %%
# define the model
lgbm = LGBMClassifier(colsample_bytree=0.8, max_depth=9, n_estimators=150,
               num_leaves=10, random_state=23)
lgbm.fit(X_train, y_train, early_stopping_rounds=20, eval_set=eval_set)
# Out:
# /Users/gregwelliver/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/gregwelliver/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.640497	valid_1's binary_logloss: 0.640159
# Training until validation scores don't improve for 20 rounds
# [2]	training's binary_logloss: 0.619325	valid_1's binary_logloss: 0.6185
# [3]	training's binary_logloss: 0.601854	valid_1's binary_logloss: 0.60063
# [4]	training's binary_logloss: 0.587333	valid_1's binary_logloss: 0.585977
# [5]	training's binary_logloss: 0.57538	valid_1's binary_logloss: 0.573729
# [6]	training's binary_logloss: 0.562439	valid_1's binary_logloss: 0.560701
# [7]	training's binary_logloss: 0.552317	valid_1's binary_logloss: 0.550598
# [8]	training's binary_logloss: 0.544576	valid_1's binary_logloss: 0.54268
# [9]	training's binary_logloss: 0.537061	valid_1's binary_logloss: 0.535072
# [10]	training's binary_logloss: 0.530619	valid_1's binary_logloss: 0.528703
# [11]	training's binary_logloss: 0.523452	valid_1's binary_logloss: 0.521431
# [12]	training's binary_logloss: 0.518625	valid_1's binary_logloss: 0.516579
# [13]	training's binary_logloss: 0.513761	valid_1's binary_logloss: 0.511669
# [14]	training's binary_logloss: 0.508291	valid_1's binary_logloss: 0.506086
# [15]	training's binary_logloss: 0.503694	valid_1's binary_logloss: 0.502026
# [16]	training's binary_logloss: 0.500107	valid_1's binary_logloss: 0.498641
# [17]	training's binary_logloss: 0.496303	valid_1's binary_logloss: 0.494787
# [18]	training's binary_logloss: 0.49331	valid_1's binary_logloss: 0.491809
# [19]	training's binary_logloss: 0.49069	valid_1's binary_logloss: 0.489393
# [20]	training's binary_logloss: 0.48842	valid_1's binary_logloss: 0.487253
# [21]	training's binary_logloss: 0.486221	valid_1's binary_logloss: 0.485725
# [22]	training's binary_logloss: 0.484053	valid_1's binary_logloss: 0.483552
# [23]	training's binary_logloss: 0.482244	valid_1's binary_logloss: 0.481697
# [24]	training's binary_logloss: 0.480195	valid_1's binary_logloss: 0.479688
# [25]	training's binary_logloss: 0.478744	valid_1's binary_logloss: 0.478481
# [26]	training's binary_logloss: 0.477241	valid_1's binary_logloss: 0.477186
# [27]	training's binary_logloss: 0.475984	valid_1's binary_logloss: 0.476216
# [28]	training's binary_logloss: 0.474855	valid_1's binary_logloss: 0.475259
# [29]	training's binary_logloss: 0.473533	valid_1's binary_logloss: 0.474021
# [30]	training's binary_logloss: 0.472349	valid_1's binary_logloss: 0.472869
# [31]	training's binary_logloss: 0.471275	valid_1's binary_logloss: 0.472084
# [32]	training's binary_logloss: 0.470476	valid_1's binary_logloss: 0.47156
# [33]	training's binary_logloss: 0.46978	valid_1's binary_logloss: 0.471233
# [34]	training's binary_logloss: 0.468952	valid_1's binary_logloss: 0.47054
# [35]	training's binary_logloss: 0.468279	valid_1's binary_logloss: 0.469939
# [36]	training's binary_logloss: 0.467559	valid_1's binary_logloss: 0.469718
# [37]	training's binary_logloss: 0.466777	valid_1's binary_logloss: 0.469209
# [38]	training's binary_logloss: 0.46609	valid_1's binary_logloss: 0.468573
# [39]	training's binary_logloss: 0.465497	valid_1's binary_logloss: 0.468077
# [40]	training's binary_logloss: 0.464924	valid_1's binary_logloss: 0.467776
# [41]	training's binary_logloss: 0.464484	valid_1's binary_logloss: 0.46735
# [42]	training's binary_logloss: 0.46394	valid_1's binary_logloss: 0.467524
# [43]	training's binary_logloss: 0.463563	valid_1's binary_logloss: 0.467433
# [44]	training's binary_logloss: 0.463079	valid_1's binary_logloss: 0.467501
# [45]	training's binary_logloss: 0.46273	valid_1's binary_logloss: 0.467353
# [46]	training's binary_logloss: 0.462341	valid_1's binary_logloss: 0.467094
# [47]	training's binary_logloss: 0.462014	valid_1's binary_logloss: 0.467098
# [48]	training's binary_logloss: 0.46164	valid_1's binary_logloss: 0.46688
# [49]	training's binary_logloss: 0.461074	valid_1's binary_logloss: 0.466899
# [50]	training's binary_logloss: 0.460764	valid_1's binary_logloss: 0.466811
# [51]	training's binary_logloss: 0.460258	valid_1's binary_logloss: 0.467379
# [52]	training's binary_logloss: 0.459764	valid_1's binary_logloss: 0.467047
# [53]	training's binary_logloss: 0.459423	valid_1's binary_logloss: 0.466741
# [54]	training's binary_logloss: 0.459202	valid_1's binary_logloss: 0.466682
# [55]	training's binary_logloss: 0.458801	valid_1's binary_logloss: 0.466356
# [56]	training's binary_logloss: 0.458304	valid_1's binary_logloss: 0.466278
# [57]	training's binary_logloss: 0.458058	valid_1's binary_logloss: 0.466423
# [58]	training's binary_logloss: 0.457806	valid_1's binary_logloss: 0.466253
# [59]	training's binary_logloss: 0.45754	valid_1's binary_logloss: 0.466311
# [60]	training's binary_logloss: 0.456967	valid_1's binary_logloss: 0.466431
# [61]	training's binary_logloss: 0.456723	valid_1's binary_logloss: 0.466457
# [62]	training's binary_logloss: 0.456487	valid_1's binary_logloss: 0.466708
# [63]	training's binary_logloss: 0.456288	valid_1's binary_logloss: 0.466593
# [64]	training's binary_logloss: 0.45592	valid_1's binary_logloss: 0.466528
# [65]	training's binary_logloss: 0.455674	valid_1's binary_logloss: 0.466413
# [66]	training's binary_logloss: 0.455439	valid_1's binary_logloss: 0.466682
# [67]	training's binary_logloss: 0.455223	valid_1's binary_logloss: 0.466775
# [68]	training's binary_logloss: 0.455062	valid_1's binary_logloss: 0.466691
# [69]	training's binary_logloss: 0.454913	valid_1's binary_logloss: 0.466902
# [70]	training's binary_logloss: 0.454384	valid_1's binary_logloss: 0.466949
# [71]	training's binary_logloss: 0.453657	valid_1's binary_logloss: 0.468053
# [72]	training's binary_logloss: 0.453469	valid_1's binary_logloss: 0.468277
# [73]	training's binary_logloss: 0.453257	valid_1's binary_logloss: 0.468427
# [74]	training's binary_logloss: 0.453128	valid_1's binary_logloss: 0.468366
# [75]	training's binary_logloss: 0.452653	valid_1's binary_logloss: 0.469888
# [76]	training's binary_logloss: 0.452358	valid_1's binary_logloss: 0.471152
# [77]	training's binary_logloss: 0.452087	valid_1's binary_logloss: 0.470886
# [78]	training's binary_logloss: 0.451734	valid_1's binary_logloss: 0.470683
# Early stopping, best iteration is:
# [58]	training's binary_logloss: 0.457806	valid_1's binary_logloss: 0.466253
# LGBMClassifier(colsample_bytree=0.8, max_depth=9, n_estimators=150,
#                num_leaves=10, random_state=23)

# %%
print("Classification Report for Training Data")
print(classification_report(y_train, lgbm.predict(X_train)))
print("Classification Report for Test Data")
print(classification_report(y_test, lgbm.predict(X_test)))
# Out:
# Classification Report for Training Data
#               precision    recall  f1-score   support
#
#            N       0.81      0.86      0.83     24940
#            Y       0.74      0.66      0.70     15053
#
#     accuracy                           0.79     39993
#    macro avg       0.78      0.76      0.77     39993
# weighted avg       0.78      0.79      0.78     39993
#
# Classification Report for Test Data
#               precision    recall  f1-score   support
#
#            N       0.80      0.87      0.83      6248
#            Y       0.75      0.64      0.69      3751
#
#     accuracy                           0.78      9999
#    macro avg       0.78      0.76      0.76      9999
# weighted avg       0.78      0.78      0.78      9999

# %%
feature_importance = lgbm.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(8,8))
plt.barh(pos, feature_importance[sorted_idx], align='center', color = 'plum')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 12

# %% [markdown]
# #### 3. How to leverage insights
#  - Ultimate black users are much more likely to retain - it would make sense to promote this feature more heavily, perhaps employ promotions to get users to adopt
#  - Shift promotional resources to King's Landing, where they have a higher retention rate.  Further investigate what the issues with retention in Astapor and Winterfell is being caused by.
#  - Improve the Android experience, which appears to be causing issues with retention.
#  - Looking at the variable importance, the most important variables are weekday_pct, and trips in first 30 days.  This underscores the importance of building a habits with this product.

# %% [markdown]
# #### write to CSV
# from pathlib import Path
# filepath = Path('X_train.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# X_train.to_csv(filepath)

# %% [markdown]
# from pathlib import Path
# filepath = Path('X_test.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# X_test.to_csv(filepath)

# %% [markdown]
# from pathlib import Path
# filepath = Path('y_train.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# y_train.to_csv(filepath)

# %% [markdown]
# from pathlib import Path
# filepath = Path('y_test.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# y_test.to_csv(filepath)
