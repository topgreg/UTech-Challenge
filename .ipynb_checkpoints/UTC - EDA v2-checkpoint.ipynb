# %% [markdown]
# # UTC - EDA
#
# Greg Welliver

# %%
# Import relevant libraries and packages.
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing 
import warnings
from scipy import stats
import re
from glob import glob, iglob
from datetime import datetime
from wordcloud import WordCloud, STOPWORDS
from datetime import datetime, timedelta


# Seaborn settings
sns.set_context('notebook')
#sns.set_style("whitegrid")
#sns.set_style("white")
style_set = sns.set_style('whitegrid')
pd.options.display.float_format = '{:,}'.format
color_choice1 = 'plum'
color_choice2 = 'lightblue'
color_choice3 = 'lightgreen'
#ax.yaxis.set_major_formatter('{x:,.0f}')
#sns.set_context('notebook', font_scale = 4)

# %matplotlib inline
import pandas as pd
#from mpl_toolkits.basemap import Basemap

import geopandas as gpd
from shapely.geometry import Point, Polygon
import contextily as ctx

from sklearn.feature_extraction.text import CountVectorizer

import json
from ydata_profiling import ProfileReport
import calendar

# %% [markdown]
# ## Load the data

# %%
# load data
df1 = pd.read_json('logins.json')
#xdf2 = pd.read_json('ultimate_data_challenge.json')

# %%
df1.head()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21

# %% [markdown]
# profile = ProfileReport(df1)
# profile

# %% [markdown]
# ### Data quality issues:
# - according to the profiling report, there are 868 duplicate rows (0.9%) - there is no need to remove these, as it is possible that two users logged in at the same time
# - there are not any nulls

# %%
days = list(calendar.day_abbr)
months = list(calendar.month_abbr)

# %%
df1[df1['login_time'] < "1970-01-01 20:30:00"]
# Out:
#             login_time
# 0  1970-01-01 20:13:18
# 1  1970-01-01 20:16:10
# 2  1970-01-01 20:16:37
# 3  1970-01-01 20:16:36
# 4  1970-01-01 20:26:21
# 5  1970-01-01 20:21:41
# 6  1970-01-01 20:12:16
# 10 1970-01-01 20:26:05

# %%
df2 = df1

# %%
df2['count'] = 1

# %%
df2 = df2.set_index('login_time')

# %%
df2
# Out:
#                      count
# login_time
# 1970-01-01 20:13:18      1
# 1970-01-01 20:16:10      1
# 1970-01-01 20:16:37      1
# 1970-01-01 20:16:36      1
# 1970-01-01 20:26:21      1
# ...                    ...
# 1970-04-13 18:50:19      1
# 1970-04-13 18:43:56      1
# 1970-04-13 18:54:02      1
# 1970-04-13 18:57:38      1
# 1970-04-13 18:54:23      1
#
# [93142 rows x 1 columns]

# %%
df2g = df2.groupby(pd.Grouper(freq='15Min')).aggregate(np.sum) 
df2g['count'] = df2g['count'].fillna(0)
df2g.head(10)
# Out:
#                      count
# login_time
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1
# 1970-01-01 21:15:00      4
# 1970-01-01 21:30:00      0
# 1970-01-01 21:45:00      4
# 1970-01-01 22:00:00      9
# 1970-01-01 22:15:00      8

# %%
df2g
# Out:
#                      count
# login_time
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1
# ...                    ...
# 1970-04-13 17:45:00      5
# 1970-04-13 18:00:00      5
# 1970-04-13 18:15:00      2
# 1970-04-13 18:30:00      7
# 1970-04-13 18:45:00      6
#
# [9788 rows x 1 columns]

# %%
df2g = df2g.reset_index()

# %%
df2g
# Out:
#               login_time  count
# 0    1970-01-01 20:00:00      2
# 1    1970-01-01 20:15:00      6
# 2    1970-01-01 20:30:00      9
# 3    1970-01-01 20:45:00      7
# 4    1970-01-01 21:00:00      1
# ...                  ...    ...
# 9783 1970-04-13 17:45:00      5
# 9784 1970-04-13 18:00:00      5
# 9785 1970-04-13 18:15:00      2
# 9786 1970-04-13 18:30:00      7
# 9787 1970-04-13 18:45:00      6
#
# [9788 rows x 2 columns]

# %%
plt.figure(figsize=(15,7))
df2g['count'].plot();

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# df[df['column_name'] == "Drake"]
# 1970-01-01 20:13:18

# %%
one_week = df2g[df2g['login_time'] < "1970-01-08"]
#y = one_month['count']
#x = one_month['login_time']
y = one_week['count']
x = one_week['login_time']



#plt.figure(figsize=(15,7))
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.show()

# %%
one_week = df2g[(df2g['login_time'] > "1970-01-08") & (df2g['login_time'] < "1970-01-15")]

y = one_week['count']
x = one_week['login_time']

#plt.figure(figsize=(15,7))
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.show()

# %%
one_week = df2g[(df2g['login_time'] > "1970-01-15") & (df2g['login_time'] < "1970-01-22")]

y = one_week['count']
x = one_week['login_time']

#plt.figure(figsize=(15,7))
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.show()

# %%
one_week = df2g[(df2g['login_time'] > "1970-01-22") & (df2g['login_time'] < "1970-01-29")]

y = one_week['count']
x = one_week['login_time']

#plt.figure(figsize=(15,7))
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.show()

# %%
one_month = df2g[df2g['login_time'] < "1970-02-01"]
y = one_month['count']
x = one_month['login_time']



#plt.figure(figsize=(15,7))
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x,y)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.show()

# %%
df2g['timestamp'] = pd.to_datetime(df2g.login_time)

# %%
df2g
# Out:
#               login_time  count           timestamp
# 0    1970-01-01 20:00:00      2 1970-01-01 20:00:00
# 1    1970-01-01 20:15:00      6 1970-01-01 20:15:00
# 2    1970-01-01 20:30:00      9 1970-01-01 20:30:00
# 3    1970-01-01 20:45:00      7 1970-01-01 20:45:00
# 4    1970-01-01 21:00:00      1 1970-01-01 21:00:00
# ...                  ...    ...                 ...
# 9783 1970-04-13 17:45:00      5 1970-04-13 17:45:00
# 9784 1970-04-13 18:00:00      5 1970-04-13 18:00:00
# 9785 1970-04-13 18:15:00      2 1970-04-13 18:15:00
# 9786 1970-04-13 18:30:00      7 1970-04-13 18:30:00
# 9787 1970-04-13 18:45:00      6 1970-04-13 18:45:00
#
# [9788 rows x 3 columns]

# %%
df2g['month'] = df2g['timestamp'].apply(lambda x: months[x.month])
df2g['day'] = df2g['timestamp'].apply(lambda x: days[x.weekday()])
df2g['hour'] = df2g['timestamp'].apply(lambda x: x.hour)
df2g['time'] = df2g['timestamp'].apply(lambda x: x.time())

# %%
df2g
# Out:
#               login_time  count           timestamp month  day  hour      time
# 0    1970-01-01 20:00:00      2 1970-01-01 20:00:00   Jan  Thu    20  20:00:00
# 1    1970-01-01 20:15:00      6 1970-01-01 20:15:00   Jan  Thu    20  20:15:00
# 2    1970-01-01 20:30:00      9 1970-01-01 20:30:00   Jan  Thu    20  20:30:00
# 3    1970-01-01 20:45:00      7 1970-01-01 20:45:00   Jan  Thu    20  20:45:00
# 4    1970-01-01 21:00:00      1 1970-01-01 21:00:00   Jan  Thu    21  21:00:00
# ...                  ...    ...                 ...   ...  ...   ...       ...
# 9783 1970-04-13 17:45:00      5 1970-04-13 17:45:00   Apr  Mon    17  17:45:00
# 9784 1970-04-13 18:00:00      5 1970-04-13 18:00:00   Apr  Mon    18  18:00:00
# 9785 1970-04-13 18:15:00      2 1970-04-13 18:15:00   Apr  Mon    18  18:15:00
# 9786 1970-04-13 18:30:00      7 1970-04-13 18:30:00   Apr  Mon    18  18:30:00
# 9787 1970-04-13 18:45:00      6 1970-04-13 18:45:00   Apr  Mon    18  18:45:00
#
# [9788 rows x 7 columns]

# %% [markdown]
# ### Let's look at logins over the course of a day, by aggregating all of the days

# %%
#df_day = pd.DataFrame(df2g.groupby('time')['count'].sum().sort_values(ascending=False).reset_index())
df_day = pd.DataFrame(df2g.groupby('time')['count'].sum().reset_index())
#df_day

fig, ax = plt.subplots(figsize = (12 , 6))
plt.title("Logins over course of day")
sns.barplot(x = 'time', y = 'count', data = df_day,
            color = color_choice1
            )

#ax.set_ylabel("Damage (USD Billions)" , size = 12 )
#ax.set_xlabel( "State / Location" , size = 12 )
#plt.xticks(rotation=90)
plt.xticks(np.arange(0, len(df_day)+1, 4))
plt.xticks(rotation=90)
;
# Out:
# ''

# %% [markdown]
# ### Let's look at logins over the course of a month

# %%
month_order = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']
#df_day = pd.DataFrame(df2g.groupby('time')['count'].sum().sort_values(ascending=False).reset_index())
df_month = pd.DataFrame(df2g.groupby('day')['count'].sum().reset_index())
#df_day

fig, ax = plt.subplots(figsize = (12 , 6))
#plt.figure(figsize=(12,6))
plt.title("Logins per month")
sns.barplot(x = 'day', y = 'count', data = df_month,
            color = color_choice3, order=month_order
            )

ax.set_ylabel("Login Count" , size = 12 )
ax.set_xlabel( "Day" , size = 12 )
ax.yaxis.set_major_formatter('{x:,.0f}')
#plt.xticks(rotation=90)
#plt.xticks(np.arange(0, len(df_month)+1, 4))
plt.xticks(rotation=45)
;
# Out:
# ''

# %%
day_order = ['Jan', 'Feb', 'Mar', 'Apr']
#df_day = pd.DataFrame(df2g.groupby('time')['count'].sum().sort_values(ascending=False).reset_index())
df_days = pd.DataFrame(df2g.groupby('month')['count'].sum().reset_index())
#df_day

fig, ax = plt.subplots(figsize = (12 , 6))
#plt.figure(figsize=(12,6))
plt.title("Logins per day of week")
sns.barplot(x = 'month', y = 'count', data = df_days,
            color = color_choice1, order=day_order
            )

#ax.set_ylabel("Damage (USD Billions)" , size = 12 )
ax.set_xlabel( "Day of Week" , size = 12 )
#plt.xticks(rotation=90)
#plt.xticks(np.arange(0, len(df_month)+1, 4))
plt.xticks(rotation=45)
;

# %%
df_states = pd.DataFrame(df2g.groupby('time')['count'].sum().sort_values(ascending=False).reset_index()[:15])
#df_states['DAMAGE_PROPERTY'] = df_states['DAMAGE_PROPERTY'] / 1000000000
#df_states

fig, ax = plt.subplots(figsize = (12 , 6))

#plt.figure(figsize=(12,6))
plt.title("Storm Damage by State / Location")
sns.barplot(x = 'time', y = 'count', data = df_states,
            color = color_choice1
            )

ax.set_ylabel("Damage (USD Billions)" , size = 12 )
ax.set_xlabel( "State / Location" , size = 12 )
#plt.xticks(rotation=90)
plt.xticks(rotation=45)
;
# Out:
# ''

# %% [markdown]
# ### brainstorm to create intervals:

# %% [markdown]
# - create a dataframe with 15 minute intervals --> start time is 15 minute intervals, and end time is beginning of interval + X number of seconds
# - column with begin time
# - column with end time
# - loop through login file and count how many logins are between those two times
